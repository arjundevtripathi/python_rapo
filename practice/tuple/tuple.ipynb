# %% [markdown]
# # 🐍 Python Tuple Data Structure — Complete Guide
# ### All Methods, Functions, Definitions & 100 Code Examples (Beginner to Advanced)
# ---
# ## 📌 What is a Tuple?
# A **Tuple** is a built-in Python data structure that:
# - Is **ordered** — items have a defined position (index)
# - Is **immutable** — once created, items cannot be changed, added, or removed
# - Allows **duplicates** — same value can appear multiple times
# - Can hold **mixed data types** — integers, strings, floats, objects, even other tuples
# - Uses **parentheses** `()` for creation (parentheses are optional in most contexts)
# - Is **faster** than lists for read-only operations
# - Can be used as **dictionary keys** (unlike lists)
# - Is **hashable** (if all elements are hashable)
#
# ```python
# my_tuple = (1, 'hello', 3.14, True, (1, 2))
# ```
#
# ## 🆚 Tuple vs List
# | Feature | Tuple | List |
# |---|---|---|
# | Syntax | `(1, 2, 3)` | `[1, 2, 3]` |
# | Mutable | ❌ No | ✅ Yes |
# | Speed | ✅ Faster | Slower |
# | Dict key | ✅ Yes | ❌ No |
# | Memory | ✅ Less | More |
# | Methods | 2 | 11 |

# %% [markdown]
# ---
# ## 📚 All Tuple Methods — Quick Reference
#
# Tuples have only **2 built-in methods** (because they are immutable):
#
# | Method | Description | Example |
# |---|---|---|
# | `count(x)` | Count occurrences of x | `(1,2,1).count(1)` → `2` |
# | `index(x)` | Return index of first occurrence of x | `(1,2,3).index(2)` → `1` |
#
# ## 📚 Built-in Functions that Work on Tuples
#
# | Function | Description |
# |---|---|
# | `len(t)` | Number of items |
# | `sum(t)` | Sum of numeric items |
# | `min(t)` | Minimum value |
# | `max(t)` | Maximum value |
# | `sorted(t)` | Returns new sorted **list** |
# | `reversed(t)` | Returns reversed iterator |
# | `enumerate(t)` | Returns (index, value) pairs |
# | `zip(t1, t2)` | Pairs items from multiple tuples |
# | `map(fn, t)` | Apply function to each item |
# | `filter(fn, t)` | Filter items by function |
# | `tuple(iterable)` | Convert iterable to tuple |
# | `any(t)` | True if any item is truthy |
# | `all(t)` | True if all items are truthy |
# | `hash(t)` | Return hash value (if all elements hashable) |
# | `type(t)` | Returns `<class 'tuple'>` |

# %%
empty = ()
also_empty = tuple()
print("Empty tuple:", empty)       
print("Type:", type(empty))
# Out:
# Empty tuple: ()
# Type: <class 'tuple'>

# %%
fruits = ('apple', 'banana', 'cherry')
marks = (85, 90, 78)
print("Fruits:", fruits)
print("Marks:", marks)
# Out:
# Fruits: ('apple', 'banana', 'cherry')
# Marks: (85, 90, 78)

# %%
marks_tuple = (50, 60, 70,40,48, 80, 90,55,65)
for mark in marks_tuple:
    if mark >= 55:
        print(mark)
# Out:
# 60
# 70
# 80
# 90
# 55
# 65

# %%
def tuple_fun(m):
    new_value=[]
    for i in m:
        if i>55:
            new_value.append(i)
    return new_value
marks_tuple = (50, 60, 70,40,48, 80, 90,55,65)
result = tuple_fun(marks_tuple)
print(result)
# Out:
# [60, 70, 80, 90, 65]

# %%
# waf to sum of all indices of a tuple
def sum_indices(t):
    total = 0
    for i in range(len(t)):
        total += i
    return total

marks_tuple = (50, 60, 70,40,48, 80, 90,55,65)  
result = sum_indices(marks_tuple)
print("Sum of indices:", result)
# Out:
# Sum of indices: 36

# %%
marks_tuple = (50, 60, 70,40,48, 80, 90,55,65)  
new_tuple = tuple(i for i in marks_tuple if i > 55)
print("New tuple:", new_tuple)
# Out:
# New tuple: (60, 70, 80, 90, 65)

# %%
marks_tuple = (50, 60, 70,40,48, 80, 90,55,65)  
print("Original tuple:", marks_tuple[::-1])
# Out:
# Original tuple: (65, 55, 90, 80, 48, 40, 70, 60, 50)

# %%
# waf to sum of all elements of indices in a tuple
marks_tuple = (50, 60, 70,40,48, 80, 90,55,65)  
s=0
for i in range(len(marks_tuple)):
    s+=i
print("Sum of elements:", s)
# Out:
# Sum of elements: 36

# %%
# wap to sum of all elements of a tuple
marks_tuple = (50, 60, 70,40,48, 80, 90,55,65)
s=0
for i in range(len(marks_tuple)):
    s+=marks_tuple[i]
print("Sum of elements:", s)
# Out:
# Sum of elements: 558
